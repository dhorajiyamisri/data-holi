# %%
import numpy as np

scalar = np.array(10)
print(scalar)
# Out:
# 10

# %%
vector = np.array([10,20,30])
print(vector)
# Out:
# [10 20 30]

# %%
matrix = np.array([[1,2],[3,4]])
print(matrix)
# Out:
# [[1 2]
#  [3 4]]

# %%
tensor = np.array([
[[1,2],[3,4]],
[[5,6],[7,8]]
])

print(tensor)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
